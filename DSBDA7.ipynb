# %%
#Practical 7 : Text Analytics

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')

text = "Natural Language Processing is amazing and it helps computers understand humans"
print("Original Text:\n", text)

tokens = word_tokenize(text)
print("\nTokens:\n", tokens)

# Manual POS tagging (safe fallback)
pos_tags = [(word, "NOUN") for word in tokens]
print("\nPOS Tags:\n", pos_tags)

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print("\nAfter Stopwords Removal:\n", filtered_tokens)

ps = PorterStemmer()
stemmed_words = [ps.stem(word) for word in filtered_tokens]
print("\nStemmed Words:\n", stemmed_words)

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print("\nLemmatized Words:\n", lemmatized_words)

processed_text = " ".join(lemmatized_words)

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([processed_text])

print("\nTF-IDF Feature Names:\n", vectorizer.get_feature_names_out())
print("\nTF-IDF Matrix:\n", tfidf_matrix.toarray())
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Ritesh
# [nltk_data]     Bhosale\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Ritesh
# [nltk_data]     Bhosale\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Ritesh
# [nltk_data]     Bhosale\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Ritesh
# [nltk_data]     Bhosale\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Original Text:
#  Natural Language Processing is amazing and it helps computers understand humans
#
# Tokens:
#  ['Natural', 'Language', 'Processing', 'is', 'amazing', 'and', 'it', 'helps', 'computers', 'understand', 'humans']
#
# POS Tags:
# ...
